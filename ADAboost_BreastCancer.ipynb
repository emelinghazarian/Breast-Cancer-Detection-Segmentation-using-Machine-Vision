# %% [markdown]
# Load the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import cv2
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from skimage.feature import hog

# %% [markdown]
# Dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("aryashah2k/breast-ultrasound-images-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/aryashah2k/breast-ultrasound-images-dataset?dataset_version_number=1...
# 100%|██████████| 195M/195M [00:04<00:00, 43.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1

# %% [markdown]
# Loading the dataset

# %%
path = "/root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/"
categories = [['benign',438],['malignant',211],['normal',134]]

images_path_list= []
mask_path_list = []

all_data_path_list = []


for i in range(len(categories)) :

    folder_path = (f'{path}/{categories[i][0]}')

    for j in range(1,categories[i][1]):

        image_path = (f'{folder_path}/{categories[i][0]} ({j}).png')
        mask_path = (f'{folder_path}/{categories[i][0]} ({j})_mask.png')

        images_path_list.append(image_path)
        mask_path_list.append(mask_path)

    data_path_df = pd.DataFrame()

    data_path_df['Image-Path'] =   images_path_list
    data_path_df['Mask-Path'] = mask_path_list
    data_path_df['Label'] = categories[i][0]

    all_data_path_list.append(data_path_df)

    images_path_list = []
    mask_path_list = []

data_path_df = pd.concat(all_data_path_list,axis = 0)
data_path_df.reset_index(drop=True,inplace=True)

data_path_df
# Out:
#                                             Image-Path  \
# 0    /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 1    /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 2    /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 3    /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 4    /root/.cache/kagglehub/datasets/aryashah2k/bre...
# ..                                                 ...
# 775  /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 776  /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 777  /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 778  /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 779  /root/.cache/kagglehub/datasets/aryashah2k/bre...
#
#                                              Mask-Path   Label
# 0    /root/.cache/kagglehub/datasets/aryashah2k/bre...  benign
# 1    /root/.cache/kagglehub/datasets/aryashah2k/bre...  benign
# 2    /root/.cache/kagglehub/datasets/aryashah2k/bre...  benign
# 3    /root/.cache/kagglehub/datasets/aryashah2k/bre...  benign
# 4    /root/.cache/kagglehub/datasets/aryashah2k/bre...  benign
# ..                                                 ...     ...
# 775  /root/.cache/kagglehub/datasets/aryashah2k/bre...  normal
# 776  /root/.cache/kagglehub/datasets/aryashah2k/bre...  normal
# 777  /root/.cache/kagglehub/datasets/aryashah2k/bre...  normal
# 778  /root/.cache/kagglehub/datasets/aryashah2k/bre...  normal
# 779  /root/.cache/kagglehub/datasets/aryashah2k/bre...  normal
#
# [780 rows x 3 columns]

# %% [markdown]
# shuffling the dataset

# %%
benign_df = data_path_df.iloc[0:133,:]

malignant_df = data_path_df.iloc[437:646,:]

normal_df = data_path_df.iloc[647:780,:]

shuffled_benign_df = benign_df.sample(133)

shuffled_malignant_df = malignant_df.sample(133)

final_df = pd.concat([shuffled_benign_df,shuffled_malignant_df,normal_df],axis=0)

final_df.reset_index(drop=True,inplace=True)

final_df

map_dic = {'benign':0,'malignant':1,'normal':2}
final_df.replace(map_dic,inplace=True)

final_df['Label'].value_counts()
# Out:
# <ipython-input-5-a2dedffb20b5>:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   final_df.replace(map_dic,inplace=True)
# Label
# 0    133
# 1    133
# 2    133
# Name: count, dtype: int64

# %%
final_df = final_df.sample(frac=1)

final_df.reset_index(inplace = True,drop = True)

final_df
# Out:
#                                             Image-Path  \
# 0    /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 1    /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 2    /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 3    /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 4    /root/.cache/kagglehub/datasets/aryashah2k/bre...
# ..                                                 ...
# 394  /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 395  /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 396  /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 397  /root/.cache/kagglehub/datasets/aryashah2k/bre...
# 398  /root/.cache/kagglehub/datasets/aryashah2k/bre...
#
#                                              Mask-Path  Label
# 0    /root/.cache/kagglehub/datasets/aryashah2k/bre...      1
# 1    /root/.cache/kagglehub/datasets/aryashah2k/bre...      1
# 2    /root/.cache/kagglehub/datasets/aryashah2k/bre...      0
# 3    /root/.cache/kagglehub/datasets/aryashah2k/bre...      0
# 4    /root/.cache/kagglehub/datasets/aryashah2k/bre...      2
# ..                                                 ...    ...
# 394  /root/.cache/kagglehub/datasets/aryashah2k/bre...      0
# 395  /root/.cache/kagglehub/datasets/aryashah2k/bre...      0
# 396  /root/.cache/kagglehub/datasets/aryashah2k/bre...      2
# 397  /root/.cache/kagglehub/datasets/aryashah2k/bre...      0
# 398  /root/.cache/kagglehub/datasets/aryashah2k/bre...      2
#
# [399 rows x 3 columns]

# %% [markdown]
# Reading the images and masks

# %%
def load_images_and_mask(image_path,mask_path,target_size = (400,400)) :

    image = cv2.imread(image_path)
    mask = cv2.imread(mask_path,cv2.IMREAD_GRAYSCALE)

    image = cv2.resize(image,target_size)
    mask = cv2.resize(mask,target_size)

    return image,mask

def load_images_NormalImage(image_path, target_size=(400, 400)):
    # Check if the image exists
    if not os.path.exists(image_path):
        print(f"Image path does not exist: {image_path}")
        return None

    image = cv2.imread(image_path)

    # Check if image is loaded successfully
    if image is None:
        print(f"Failed to load image: {image_path}")
        return None

    # Resize the image if loaded correctly
    image = cv2.resize(image, target_size)

    return image

# %% [markdown]
# Extract HOG Features

# %%
def hog_extractor(image,mask) :

    masked_image = cv2.bitwise_and(image,image,mask=mask)

    gray_image = cv2.cvtColor(masked_image,cv2.COLOR_BGR2GRAY)

    features,hot_image = hog(gray_image,pixels_per_cell=(16,16),cells_per_block=(2,2),visualize=True)

    return features

def hog_extractor_NormalImage(image) :

    gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

    features,hot_image = hog(gray_image,pixels_per_cell=(16,16),cells_per_block=(2,2),visualize=True)

    return features

# %%
image_path = final_df.loc[0, 'Image-Path']
print(f"Checking if this image exists: {image_path}")
# Out:
# Checking if this image exists: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (86).png

# %%
# !ls /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT/
# Out:
# benign	malignant  normal

# %%
from PIL import Image

# Try to open the image with Pillow to check if it works
try:
    pil_image = Image.open(image_path)
    pil_image.show()  # This will display the image
    print(f"Image loaded successfully using Pillow: {image_path}")
except Exception as e:
    print(f"Error opening image with Pillow: {e}")
# Out:
# Image loaded successfully using Pillow: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (86).png

# %%
X = []
Y = []

for rows in range(len(final_df)):
    image_path = final_df.loc[rows, 'Image-Path']

    # Check if the image is loaded properly
    print(f"Processing: {image_path}")

    # Load the normal image
    image = load_images_NormalImage(image_path=image_path)

    # Skip processing if the image is None
    if image is None:
        continue

    try:
        # Extract HOG features
        features = hog_extractor_NormalImage(image)
        if len(features) == 0:
            print(f"Skipping row {rows} because no features were extracted.")
            continue

        X.append(features)
        Y.append(final_df.loc[rows, 'Label'])

    except Exception as e:
        print(f"Error processing row {rows}: {e}")
        continue

print(f"Length of X after loop: {len(X)}")
print(f"Length of Y after loop: {len(Y)}")

if len(X) > 0 and len(Y) > 0:
    X = np.array(X)
    Y = np.array(Y)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
else:
    print("No valid data to split. Please check the data processing.")
# Out:
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (86).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (59).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (128).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (8).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (35).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (156).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (24).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (115).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (84).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (102).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (127).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (133).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (12).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (142).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (197).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (98).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (30).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (108).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (27).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (41).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (158).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (112).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (66).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (178).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (68).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (73).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (99).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (203).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (100).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (9).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (67).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (113).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (205).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (206).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (71).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (201).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (123).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (29).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (90).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (46).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (66).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (3).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (131).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (50).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (107).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (30).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (80).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (62).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (58).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (7).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (153).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (37).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (149).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (133).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (57).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (49).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (11).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (33).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (95).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (83).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (62).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (48).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (188).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (1).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (62).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (120).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (100).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (32).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (192).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (109).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (79).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (200).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (120).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (70).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (96).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (33).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (129).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (132).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (4).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (122).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (40).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (91).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (128).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (4).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (99).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (3).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (101).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (57).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (127).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (191).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (47).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (52).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (74).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (100).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (134).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (111).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (131).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (136).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (42).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (10).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (51).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (84).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (94).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (151).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (116).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (44).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (102).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (39).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (43).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (7).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (5).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (6).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (15).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (145).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (61).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (60).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (87).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (98).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (40).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (112).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (95).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (84).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (82).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (32).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (67).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (22).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (83).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (90).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (11).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (7).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (77).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (132).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (85).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (93).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (69).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (48).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (66).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (1).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (139).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (46).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (49).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (131).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (79).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (137).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (88).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (104).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (61).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (23).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (126).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (13).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (33).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (121).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (96).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (208).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (190).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (31).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (125).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (88).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (55).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (81).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (117).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (106).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (89).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (38).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (115).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (129).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (162).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (56).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (16).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (42).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (9).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (20).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (17).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (36).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (25).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (93).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (50).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (72).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (114).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (95).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (13).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (82).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (122).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (106).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (68).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (195).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (10).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (9).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (155).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (4).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (54).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (67).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (125).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (28).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (92).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (64).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (28).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (180).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (147).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (36).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (111).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (87).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (72).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (111).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (79).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (53).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (97).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (71).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (130).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (123).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (107).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (16).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (184).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (92).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (81).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (120).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (63).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (52).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (19).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (108).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (65).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (117).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (125).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (18).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (172).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (15).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (68).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (14).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (75).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (19).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (29).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (10).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (28).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (14).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (119).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (31).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (57).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (166).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (76).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (99).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (58).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (121).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (43).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (20).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (60).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (77).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (24).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (106).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (116).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (124).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (94).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (45).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (50).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (51).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (105).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (117).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (176).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (80).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (169).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (69).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (110).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (103).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (130).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (6).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (119).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (109).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (64).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (103).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (110).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (143).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (105).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (170).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (38).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (16).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (52).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (63).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (21).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (126).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (25).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (124).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (55).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (91).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (104).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (21).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (199).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (46).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (2).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (37).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (89).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (83).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (71).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (97).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (124).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (65).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (132).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (152).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (55).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (26).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (60).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (118).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (2).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (54).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (186).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (26).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (74).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (179).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (32).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (73).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (17).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (126).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (104).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (21).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (187).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (49).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (110).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (35).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (78).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (90).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (93).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (86).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (25).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (69).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (18).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (36).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (59).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (2).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (75).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (44).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (150).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (78).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (48).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (122).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (123).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (207).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (23).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (41).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (85).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (11).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (47).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (30).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (74).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (87).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (34).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (127).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (94).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (163).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (113).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (174).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (91).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (146).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (8).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (76).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (204).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (89).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (119).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (80).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (40).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (3).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (96).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (101).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (43).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (72).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (70).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (12).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (53).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (47).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (18).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (168).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (159).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (118).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (148).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (44).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (103).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (193).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (45).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (114).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (6).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (121).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (92).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (14).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (86).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (19).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (29).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (114).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (109).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (56).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (22).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (27).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (34).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (129).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (116).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (82).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//malignant/malignant (175).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (20).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (65).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (5).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (39).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//benign/benign (1).png
# Processing: /root/.cache/kagglehub/datasets/aryashah2k/breast-ultrasound-images-dataset/versions/1/Dataset_BUSI_with_GT//normal/normal (59).png
# Length of X after loop: 399
# Length of Y after loop: 399

# %% [markdown]
# Define A Function To Evalute

# %%
def evaluate(Y_prediction,name):

    report = classification_report(y_true=Y_test,y_pred=Y_prediction)

    print(report)

    print('\n---------------------------------------------------------------------------------------------------------------\n')

    conf_matrix = confusion_matrix(y_true=Y_test,y_pred=Y_prediction)

    plt.figure(figsize=(8,5))

    sns.heatmap(conf_matrix,annot=True,cmap='Blues')

    plt.xlabel('Predicted Label')

    plt.ylabel('True Label')

    plt.title(f'{name} Evaluation')

    plt.show()

# %% [markdown]
# Feature extraction with CNN

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA

# Preprocessing function
def preprocess_image(image_path, target_size=(224, 224)):
    img = image.load_img(image_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return preprocess_input(img_array)

# Load VGG16 model pre-trained on ImageNet
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
feature_extractor = Model(inputs=base_model.input, outputs=base_model.output)

# Prepare X and Y arrays for features and labels
X = []
Y = []

#extract features
for index, row in final_df.iterrows():
    image_path = row['Image-Path']
    label = row['Label']

    processed_image = preprocess_image(image_path)
    features = feature_extractor.predict(processed_image)
    features_flat = features.flatten()

    X.append(features_flat)
    Y.append(label)


X = np.array(X)
Y = np.array(Y)

# Apply PCA for dimensionality reduction
pca = PCA(n_components=100)
X_reduced = pca.fit_transform(X)

X_train, X_test, Y_train, Y_test = train_test_split(X_reduced, Y, test_size=0.2, random_state=42)


X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 897ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 784ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 986ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 578ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 576ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 853ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 910ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 803ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 892ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 997ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 839ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 998ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 888ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 721ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 992ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 996ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 825ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 992ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 862ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1000ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 913ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 887ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 893ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 948ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 722ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 843ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 996ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 882ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 983ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 881ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 694ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 977ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 904ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 918ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 810ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 929ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 808ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 969ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 885ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step

# %%
print(f"Feature shape: {X.shape}, Labels shape: {Y.shape}")
print(f"Training set size: {X_train.shape}, Test set size: {X_test.shape}")
# Out:
# Feature shape: (399, 25088), Labels shape: (399,)
# Training set size: (319, 100), Test set size: (80, 100)

# %% [markdown]
# ADAboost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.tree import DecisionTreeClassifier

# Initialize the AdaBoost classifier with a DecisionTreeClassifier as the base estimator
base_estimator = DecisionTreeClassifier(max_depth=1)  # Weak learner
ada_classifier = AdaBoostClassifier(
    estimator=base_estimator,  # Use 'estimator' instead of 'base_estimator'
    n_estimators=100,  # Number of boosting rounds
    learning_rate=1.0,
    random_state=42
)

# Train the classifier on the training data
ada_classifier.fit(X_train_pca, Y_train)

# Make predictions on the test data
Y_pred = ada_classifier.predict(X_test_pca)

# Evaluate the classifier's performance
print("Classification Report:")
print(classification_report(Y_test, Y_pred))

print("Accuracy:", accuracy_score(Y_test, Y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.44      0.52        25
#            1       0.58      0.66      0.61        29
#            2       0.67      0.77      0.71        26
#
#     accuracy                           0.62        80
#    macro avg       0.63      0.62      0.62        80
# weighted avg       0.63      0.62      0.62        80
#
# Accuracy: 0.625

# %% [markdown]
# using grid search for adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score

# Grid Search for AdaBoost
def adaboost_with_grid_search(X_train, Y_train, X_test, Y_test):
    # Define the parameter grid for hyperparameter tuning
    param_grid = {
        'n_estimators': [50, 100, 150],  # Number of boosting rounds
        'learning_rate': [0.1, 0.5, 1.0],  # Learning rate
        'estimator__max_depth': [1, 2, 3]  # Maximum depth of the decision tree base estimator
    }

    # Initialize the base estimator
    base_estimator = DecisionTreeClassifier(random_state=42)

    # Initialize AdaBoostClassifier
    ada_classifier = AdaBoostClassifier(
        estimator=base_estimator,
        random_state=42
    )

    # Perform GridSearchCV for hyperparameter tuning
    grid_search = GridSearchCV(
        estimator=ada_classifier,
        param_grid=param_grid,
        scoring='accuracy',
        cv=5,  # 5-fold cross-validation
        n_jobs=-1  # Use all available CPU cores
    )

    print("Running Grid Search for AdaBoost...")
    grid_search.fit(X_train, Y_train.ravel())

    # Get the best model and parameters
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_
    print(f"\nBest Parameters: {best_params}")
    print(f"Cross-Validation Accuracy: {grid_search.best_score_:.4f}")

    # Evaluate on the test set
    test_accuracy = best_model.score(X_test, Y_test)
    print(f"\nTest Accuracy: {test_accuracy:.4f}")

    # Make predictions on the test set
    Y_pred = best_model.predict(X_test)

    # Print evaluation metrics
    print("\nClassification Report:")
    print(classification_report(Y_test, Y_pred))

    print("\nAccuracy:", accuracy_score(Y_test, Y_pred))

    return best_model

# %%
# Call the function to train and evaluate the model
best_ada_model = adaboost_with_grid_search(X_train_pca, Y_train, X_test_pca, Y_test)
# Out:
# Running Grid Search for AdaBoost...
#
# Best Parameters: {'estimator__max_depth': 3, 'learning_rate': 0.1, 'n_estimators': 150}
# Cross-Validation Accuracy: 0.8023
#
# Test Accuracy: 0.8500
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83        24
#            1       0.86      0.75      0.80        24
#            2       0.86      0.94      0.90        32
#
#     accuracy                           0.85        80
#    macro avg       0.85      0.84      0.84        80
# weighted avg       0.85      0.85      0.85        80
#
#
# Accuracy: 0.85

# %% [markdown]
# save the model

# %%
import joblib

# Save the trained model
joblib.dump(best_ada_model, 'best_ada_model.pkl')

print("Model saved as 'best_ada_model.pkl'")

# Load the model later
loaded_model = joblib.load('best_ada_model.pkl')
# Out:
# Model saved as 'best_ada_model.pkl'

# %%
# Evaluate accuracy on the training set
train_accuracy = best_ada_model.score(X_train_pca, Y_train)
print(f"Training Accuracy: {train_accuracy:.4f}")

# Evaluate accuracy on the testing set
test_accuracy = best_ada_model.score(X_test_pca, Y_test)
print(f"Testing Accuracy: {test_accuracy:.4f}")

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (1.4.2)

# %%
import joblib

# Save the trained model to a .joblib file
joblib.dump(best_ada_model, 'best_ada_model.joblib')

print("Model saved as 'best_ada_model.joblib'")
# Out:
# Model saved as 'best_ada_model.joblib'

# %% [markdown]
# Grid Search for AdaBoost with PCA Features

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score

# Grid Search for AdaBoost with PCA Features
def adaboost_with_grid_search_pca(X_train_pca, Y_train, X_test_pca, Y_test):
    """
    Perform AdaBoost classification with Grid Search hyperparameter tuning using PCA features.
    """
    # Define the parameter grid for hyperparameter tuning
    param_grid = {
        'n_estimators': [50, 100, 150],  # Number of boosting rounds
        'learning_rate': [0.1, 0.5, 1.0],  # Learning rate
        'estimator__max_depth': [1, 2, 3]  # Maximum depth of the decision tree base estimator
    }

    # Initialize the base estimator
    base_estimator = DecisionTreeClassifier(random_state=42)

    # Initialize AdaBoostClassifier
    ada_classifier = AdaBoostClassifier(
        estimator=base_estimator,
        random_state=42
    )

    # Perform GridSearchCV for hyperparameter tuning
    grid_search = GridSearchCV(
        estimator=ada_classifier,
        param_grid=param_grid,
        scoring='accuracy',
        cv=5,  # 5-fold cross-validation
        n_jobs=-1  # Use all available CPU cores
    )

    print("Running Grid Search for AdaBoost...")
    grid_search.fit(X_train_pca, Y_train.ravel())

    # Get the best model and parameters
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_
    print(f"\nBest Parameters: {best_params}")
    print(f"Cross-Validation Accuracy: {grid_search.best_score_:.4f}")

    # Evaluate on the test set
    test_accuracy = best_model.score(X_test_pca, Y_test)
    print(f"\nTest Accuracy: {test_accuracy:.4f}")

    # Make predictions on the test set
    Y_pred = best_model.predict(X_test_pca)

    # Print evaluation metrics
    print("\nClassification Report:")
    print(classification_report(Y_test, Y_pred))

    print("\nAccuracy:", accuracy_score(Y_test, Y_pred))

    return best_model

# %%
# Call the function to train and evaluate the model
best_ada_model_pca = adaboost_with_grid_search_pca(X_train_pca, Y_train, X_test_pca, Y_test)
# Out:
# Running Grid Search for AdaBoost...
#
# Best Parameters: {'estimator__max_depth': 3, 'learning_rate': 0.1, 'n_estimators': 150}
# Cross-Validation Accuracy: 0.8023
#
# Test Accuracy: 0.8500
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83        24
#            1       0.86      0.75      0.80        24
#            2       0.86      0.94      0.90        32
#
#     accuracy                           0.85        80
#    macro avg       0.85      0.84      0.84        80
# weighted avg       0.85      0.85      0.85        80
#
#
# Accuracy: 0.85

# %%
import h5py

# Save data to an .h5 file
with h5py.File('features_and_labels.h5', 'w') as h5file:
    # Save training and testing features
    h5file.create_dataset('X_train', data=X_train)
    h5file.create_dataset('X_test', data=X_test)
    # Save training and testing labels
    h5file.create_dataset('Y_train', data=Y_train)
    h5file.create_dataset('Y_test', data=Y_test)

print("Features and labels saved to 'features_and_labels.h5'")
# Out:
# Features and labels saved to 'features_and_labels.h5'

# %% [markdown]
# Randomized Search for AdaBoost with PCA Features

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report, accuracy_score

# Randomized Search for AdaBoost with PCA Features
def adaboost_with_random_search_pca(X_train_pca, Y_train, X_test_pca, Y_test):
    """
    Perform AdaBoost classification with Randomized Search hyperparameter tuning using PCA features.
    """
    # Define the parameter grid for hyperparameter tuning
    param_dist = {
        'n_estimators': [50, 100, 150, 200, 250],  # Number of boosting rounds
        'learning_rate': [0.01, 0.1, 0.5, 1.0, 1.5],  # Learning rate
        'estimator__max_depth': [1, 2, 3, 4]  # Maximum depth of the decision tree base estimator
    }

    # Initialize the base estimator
    base_estimator = DecisionTreeClassifier(random_state=42)

    # Initialize AdaBoostClassifier
    ada_classifier = AdaBoostClassifier(
        estimator=base_estimator,
        random_state=42
    )

    # Perform RandomizedSearchCV for hyperparameter tuning
    random_search = RandomizedSearchCV(
        estimator=ada_classifier,
        param_distributions=param_dist,
        n_iter=20,  # Number of parameter settings sampled
        scoring='accuracy',
        cv=5,  # 5-fold cross-validation
        random_state=42,
        n_jobs=-1  # Use all available CPU cores
    )

    print("Running Randomized Search for AdaBoost...")
    random_search.fit(X_train_pca, Y_train.ravel())

    # Get the best model and parameters
    best_model = random_search.best_estimator_
    best_params = random_search.best_params_
    print(f"\nBest Parameters: {best_params}")
    print(f"Cross-Validation Accuracy: {random_search.best_score_:.4f}")

    # Evaluate on the test set
    test_accuracy = best_model.score(X_test_pca, Y_test)
    print(f"\nTest Accuracy: {test_accuracy:.4f}")

    # Make predictions on the test set
    Y_pred = best_model.predict(X_test_pca)

    # Print evaluation metrics
    print("\nClassification Report:")
    print(classification_report(Y_test, Y_pred))

    print("\nAccuracy:", accuracy_score(Y_test, Y_pred))

    return best_model

# %%
# Call the function to train and evaluate the model
best_ada_model_random = adaboost_with_random_search_pca(X_train_pca, Y_train, X_test_pca, Y_test)
# Out:
# Running Randomized Search for AdaBoost...
#
# Best Parameters: {'n_estimators': 200, 'learning_rate': 0.1, 'estimator__max_depth': 4}
# Cross-Validation Accuracy: 0.7805
#
# Test Accuracy: 0.9250
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91        24
#            1       0.88      0.92      0.90        24
#            2       0.94      0.97      0.95        32
#
#     accuracy                           0.93        80
#    macro avg       0.92      0.92      0.92        80
# weighted avg       0.93      0.93      0.92        80
#
#
# Accuracy: 0.925

# %% [markdown]
# save the model

# %%
import joblib

# Save the trained model
joblib.dump(best_ada_model_random, 'best_ada_model_random.pkl')

print("Model saved as 'best_ada_model_random.pkl'")

# Load the model later
loaded_model = joblib.load('best_ada_model_random.pkl')
# Out:
# Model saved as 'best_ada_model_random.pkl'

# %%
import joblib

# Save the trained model to a .joblib file
joblib.dump(best_ada_model_random, 'best_ada_model_random.joblib')

print("Model saved as 'best_ada_model_random.joblib'")
# Out:
# Model saved as 'best_ada_model_random.joblib'
